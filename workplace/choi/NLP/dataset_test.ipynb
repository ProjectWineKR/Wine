# %%
import requests
import json
from urllib.request import Request, urlopen

from pprint import pprint
import pandas as pd
from pandas.io.json import json_normalize

# %%
#Test API
headers = {
  'Accept': 'application/json',
  'Authorization': 'Token 654181698a2795632e508be926ce4c021f431418'
}
request = Request('https://api.globalwinescore.com/globalwinescores/latest/?wine_id=114959', headers=headers)

response_body1 = urlopen(request).read()
data=json.loads(response_body1)
# print(data)
json_normalize(data['results'])
# print (response_body)
# response_body1.splitlines()
# Out:
#                wine  wine_id       wine_slug appellation appellation_slug  \
# 0   Petrus, Pomerol   114959  petrus-pomerol     Pomerol          pomerol
# 1   Petrus, Pomerol   114959  petrus-pomerol     Pomerol          pomerol
# 2   Petrus, Pomerol   114959  petrus-pomerol     Pomerol          pomerol
# 3   Petrus, Pomerol   114959  petrus-pomerol     Pomerol          pomerol
# 4   Petrus, Pomerol   114959  petrus-pomerol     Pomerol          pomerol
# 5   Petrus, Pomerol   114959  petrus-pomerol     Pomerol          pomerol
# 6   Petrus, Pomerol   114959  petrus-pomerol     Pomerol          pomerol
# 7   Petrus, Pomerol   114959  petrus-pomerol     Pomerol          pomerol
# 8   Petrus, Pomerol   114959  petrus-pomerol     Pomerol          pomerol
# 9   Petrus, Pomerol   114959  petrus-pomerol     Pomerol          pomerol
# 10  Petrus, Pomerol   114959  petrus-pomerol     Pomerol          pomerol
# 11  Petrus, Pomerol   114959  petrus-pomerol     Pomerol          pomerol
# ...

# %%
#Extract all Wine ID

headers = {
  'Accept': 'application/json',
  'Authorization': 'Token 654181698a2795632e508be926ce4c021f431418'
}
request = Request('https://api.globalwinescore.com/globalwinescores/latest/?color=red&limit=10000', headers=headers)

response_body = urlopen(request).read()
print(response_body)
fulldata_red=json.loads(response_body)
json_normalize(fulldata_red['results'])
# Out:
# egions":["Bordeaux"],"country":"France","classification":null,"vintage":"2003","date":"2018-03-29","is_primeurs":false,"score":84.74,"confidence_index":"C","journalist_count":4,"lwin":1008326,"lwin_11":10083262003},{"wine":"Chateau Labegorce Margaux, Margaux","wine_id":37834,"wine_slug":"chateau-labegorce-margaux-margaux","appellation":"Margaux","appellation_slug":"margaux","color":"Red","wine_type":"","regions":["Bordeaux"],"country":"France","classification":null,"vintage":"2001","date":"2018-03-29","is_primeurs":false,"score":84.74,"confidence_index":"B","journalist_count":7,"lwin":1011797,"lwin_11":10117972001},{"wine":"Chateau Du Glana, Saint Julien","wine_id":35366,"wine_slug":"chateau-du-glana-saint-julien","appellation":"Saint Julien","appellation_slug":"saint-julien","color":"Red","wine_type":"","regions":["Bordeaux"],"country":"France","classification":null,"vintage":"2013","date":"2018-03-29","is_primeurs":false,"score":84.73,"confidence_index":"B","journalist_count":5,"lw
# ...

# %%
#Get White Wine
headers = {
  'Accept': 'application/json',
  'Authorization': 'Token 654181698a2795632e508be926ce4c021f431418'
}
request = Request('https://api.globalwinescore.com/globalwinescores/latest/?color=white&limit=10000', headers=headers)

response_body2 = urlopen(request).read()
# print(response_body2)
fulldata_white=json.loads(response_body2)
white=pd.DataFrame(json_normalize(fulldata_white['results']))
white.describe()
white.color.unique()
# Out:
# array(['White'], dtype=object)

# %%
# Load Data into SQL

# %%
# !pip install psycopg2
# Out:
# ig to the PATH
#     or specify the full executable path with the option:
#
#         python setup.py build_ext --pg-config /path/to/pg_config build ...
#
#     or with the pg_config option in 'setup.cfg'.
#     ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/ce/2d/e9e65ee32ef2657028109bd5a1c1ece97e409ebf790b6ee286aae2c6b890/psycopg2-2.4.tar.gz#sha256=f41623c413283f101b61ba2356f92cc1890b00308aea970124ebd6178ac5c3a5 (from https://pypi.org/simple/psycopg2/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
# ...
#      |████████████████████████████████| 568 kB 8.2 MB/s
#     ERROR: Command errored out with exit status 1:
# ...

# %%
import psycopg2
from sqlalchemy import create_engine

connection_string = "postgres:1988Ysl_5@localhost:5432/Winescore"
engine2 = create_engine(f'postgresql://{connection_string}')
engine2.table_names()
# conn=psycopg2.connect("host=localhost dbname=Winescore")
# cur = conn.cursor()
# cur.execute('SELECT * FROM winescore')

# %%
white.to_sql(name="winescore",con=engine2,if_exists='append',index=False)
red.to_sql(name="winescore",con=engine2,if_exists='append',index=False)
